# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import pandas as pd
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from sklearn.svm import SVC

# %% [markdown]
# # Load data

# %%
data = pd.read_excel('./Table S2.xlsx')
cols5 = ['qtype','Al', 'Ti', 'Li','Ge', 'Sr']
for ele in cols5[1:]:
    data[ele] = pd.to_numeric(data[ele], errors='coerce')
df5 = data.loc[: , cols5].dropna()
print(len(df5))    # number of samples
df5.qtype.value_counts() # number of samples in each class
# Out:
# 1690
# orogenic      339
# greisen       325
# porphyry      272
# granite       237
# skarn         203
# carlin        127
# IRG            96
# pegmatite      65
# epithermal     26
# Name: qtype, dtype: int64

# %%
X = df5.drop('qtype', axis=1).astype(float)
y = df5['qtype']

# %%
# split the data set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2)

# samples in testset for each class
y_test.value_counts()
# Out:
# greisen       64
# orogenic      63
# porphyry      57
# granite       51
# skarn         39
# carlin        24
# IRG           20
# pegmatite     14
# epithermal     6
# Name: qtype, dtype: int64

# %% [markdown]
# # Make Pipeline

# %%
log_transformer = FunctionTransformer(np.log, validate=True)
pipe_clf = make_pipeline(log_transformer, StandardScaler(), SVC())
pipe_clf
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<ufunc 'log'>, validate=True)),
#                 ('standardscaler', StandardScaler()), ('svc', SVC())])

# %% [markdown]
# # Parameter estimation using grid search with cross-validation

# %%
class MidpointNormalize(Normalize):

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %%
C_range = np.logspace(-2, 8, 16 , base=2)
gamma_range = np.logspace(-5, 3, 16, base=2)

param_grid = {'svc__kernel': ['rbf'], 'svc__gamma': gamma_range,
                     'svc__C': C_range}                   
cv = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=2)

# %%
grid = GridSearchCV(pipe_clf, param_grid=param_grid, cv=cv, scoring='f1_macro', n_jobs=-1)
grid.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters are {'svc__C': 10.079368399158984, 'svc__gamma': 0.2871745887492588, 'svc__kernel': 'rbf'} with a score of 0.85

# %%
# Visualization

scores = grid.cv_results_['mean_test_score'].reshape(len(C_range),
                                                     len(gamma_range))
plt.figure(figsize=(10, 8))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.cividis,
           norm=MidpointNormalize(vmin=0.2, midpoint=0.8))
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45, ha='right')
plt.yticks(np.arange(len(C_range)), C_range)
plt.title('Validation accuracy')
plt.show()

# %% [markdown]
# # Model retrain

# %%
log_transformer = FunctionTransformer(np.log, validate=True)
pipe_clf = make_pipeline(log_transformer, StandardScaler(),
                         SVC(C=grid.best_params_['svc__C'], kernel='rbf', probability = True,
                             gamma=grid.best_params_['svc__gamma'], cache_size=1000))

# %%
pipe_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<ufunc 'log'>, validate=True)),
#                 ('standardscaler', StandardScaler()),
#                 ('svc',
#                  SVC(C=10.079368399158984, cache_size=1000,
#                      gamma=0.2871745887492588, probability=True))])

# %%
y_pred = pipe_clf.predict(X_test)
pred_train = pipe_clf.predict(X_train)
probility = pipe_clf.predict_proba(X_test)
y_pred2 = y_pred.reshape((y_pred.shape[0],1))

# %%
res = np.concatenate([y_pred2, probility], axis=1)
res = pd.DataFrame(res, columns= ['pred_qtype','IRG', 'carlin','epithermal', 'granite', 'greisen', 'orogenic', 'pegmatite', 'porphyry', 'skarn'])
res
# Out:
#     pred_qtype          IRG       carlin  epithermal      granite  \
# 0     orogenic   0.00175224   0.00232599  0.00278802   0.00111791
# 1       carlin   0.00308355     0.902635  0.00944185   0.00376492
# 2     orogenic  0.000571017  0.000523918  0.00228775  0.000912657
# 3     orogenic     0.317369   0.00127612  0.00698319     0.002109
# 4        skarn   0.00415984   0.00512171   0.0137625   0.00412635
# ..         ...          ...          ...         ...          ...
# 333   orogenic   0.00231471   0.00107475   0.0132173  0.000299611
# 334    granite    0.0011648   0.00134222  0.00152243     0.926235
# 335  pegmatite   0.00996916    0.0123727   0.0148334    0.0183301
# 336        IRG     0.762962   0.00102138   0.0164369  0.000870041
# 337   orogenic    0.0521952   0.00141798  0.00121118   0.00826639
#
#          greisen    orogenic    pegmatite    porphyry       skarn
# 0     0.00217546    0.982063   0.00053649  0.00210558  0.00513515
# 1      0.0156087   0.0248191    0.0162502  0.00605087   0.0183455
# 2       0.125544    0.859744   0.00684229   0.0012419  0.00233217
# 3      0.0063041    0.474994   0.00726287   0.0298631     0.15384
# 4      0.0115464   0.0639624    0.0250448     0.24521    0.627066
# ..           ...         ...          ...         ...         ...
# 333  0.000263933    0.946447    0.0031008  0.00475374   0.0285277
# 334    0.0389937  0.00132823    0.0197572  0.00378786  0.00586834
# 335    0.0206564   0.0260052     0.847754    0.021496   0.0285827
# 336   0.00436213  0.00517732      0.13342   0.0308827   0.0448673
# 337    0.0042672    0.813491  0.000316785  0.00278023    0.116054
#
# [338 rows x 10 columns]

# %%
# train set report
print(classification_report(y_train, pred_train))
# Out:
#               precision    recall  f1-score   support
#
#          IRG       0.84      0.88      0.86        76
#       carlin       0.98      1.00      0.99       103
#   epithermal       1.00      0.95      0.97        20
#      granite       0.90      0.96      0.93       186
#      greisen       0.88      0.91      0.90       261
#     orogenic       0.94      0.90      0.92       276
#    pegmatite       0.96      0.86      0.91        51
#     porphyry       0.93      0.93      0.93       215
#        skarn       0.90      0.84      0.87       164
#
#     accuracy                           0.91      1352
#    macro avg       0.92      0.92      0.92      1352
# weighted avg       0.91      0.91      0.91      1352

# %%
# final evaluation
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          IRG       0.86      0.90      0.88        20
#       carlin       0.92      1.00      0.96        24
#   epithermal       1.00      1.00      1.00         6
#      granite       0.90      0.92      0.91        51
#      greisen       0.79      0.91      0.85        64
#     orogenic       0.87      0.83      0.85        63
#    pegmatite       1.00      0.64      0.78        14
#     porphyry       0.89      0.84      0.86        57
#        skarn       0.78      0.74      0.76        39
#
#     accuracy                           0.86       338
#    macro avg       0.89      0.86      0.87       338
# weighted avg       0.86      0.86      0.86       338
#
# [[18  0  0  0  0  2  0  0  0]
#  [ 0 24  0  0  0  0  0  0  0]
#  [ 0  0  6  0  0  0  0  0  0]
#  [ 0  0  0 47  2  2  0  0  0]
#  [ 0  0  0  3 58  0  0  2  1]
#  [ 0  1  0  1  3 52  0  1  5]
#  [ 1  0  0  1  1  0  9  2  0]
#  [ 0  0  0  0  6  1  0 48  2]
#  [ 2  1  0  0  3  3  0  1 29]]

# %%
# heatmap the confusion matrix of test data
#---------------------------------------------------------------------
label_order = ['IRG', 'carlin','epithermal', 'granite', 'greisen', 'orogenic', 'pegmatite', 'porphyry', 'skarn']
for i in range(len(label_order)):
    if label_order[i] == 'IRG':
        pass
    else:
        label_order[i] = label_order[i].capitalize()
#-------------------------------------------------------------------
cm = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns=label_order, index=label_order)

f, ax = plt.subplots(figsize=(4.75, 4.1))
sns.heatmap(cm, annot=True, fmt="d", linewidths=.5, ax=ax, cmap='YlGn')
ax.set_title('Confusion matrix of test set', fontsize=12)
ax.set_xlabel('Predictions', fontsize=12)
ax.set_ylabel('True labels', fontsize=12)

plt.xticks(rotation=270)
plt.tight_layout()
# f.suptitle('Fig. 5', x=0.05)
# f.savefig('./figures/confusion_matrix.png', dpi=300)
# f.savefig('./figures/confusion_matrix.pdf', dpi=150)

# %% [markdown]
# # Model persistence

# %%
from joblib import dump, load
dump(pipe_clf, 'quartz_clf.joblib')
# Out:
# ['quartz_clf.joblib']
